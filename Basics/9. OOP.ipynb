# %%
# define a class
class student:
    course = "MSBA7001" # class attribute

    def __init__(self, name, score):  # instance attributes
        self.name = name
        self.score = score

    def __str__(self):   # string representation
        return f"{self.name} earned {self.score} in {self.course}."

    def passed(self, cutoff = 75):   # instance method
        return True if self.score > cutoff else False

    def printout(self):   # instance method
        if self.passed():
            print(f"{self.name} passed the course.")
        else:
            print(f"{self.name} failed the course.")

# %%
# instantiation
chao = student("Chao", 90)
eric = student("Eric", 60)

# %%
# class attribute
student.course, chao.course, eric.course
# Out:
# ('MSBA7001', 'MSBA7001', 'MSBA7001')

# %%
# instance attributes
chao.name, eric.score
# Out:
# ('Chao', 60)

# %%
# string representation
print(chao)
# Out:
# Chao earned 90 in MSBA7001.

# %%
# instance method
chao.passed(), eric.passed()
# Out:
# (True, False)

# %%
# instance method
chao.printout()
# Out:
# Chao passed the course.

# %%
eric.printout()
# Out:
# Eric failed the course.

# %%
# import class from .py file
from example import student as st

meili = st("Meili", 88)
meili.printout()
# Out:
# Meili passed the course.

# %%
print(dir(st))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'course', 'passed', 'printout']
