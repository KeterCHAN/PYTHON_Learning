# %% [markdown]
# # Boolean expressions

# %% [markdown]
# ## Comparison operators

# %%
5 > 2
# Out:
# True

# %%
5 == 3
# Out:
# False

# %%
5/2 == 2.5
# Out:
# True

# %%
a = 2.5
b = 2.5

# %% [markdown]
# **About the `is` operator**
# <br>`is` checks whether both the operands refer to the same object or not, i.e., the same id.
# <br>`==` compares the values only.

# %%
a is b
# Out:
# False

# %%
a == b
# Out:
# True

# %%
print(id(a), id(b))
# Out:
# 2251257629136 2251235602480

# %%
2.5 is 2.5
# Out:
# <>:1: SyntaxWarning: "is" with 'float' literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with 'float' literal. Did you mean "=="?
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_44540\229312583.py:1: SyntaxWarning: "is" with 'float' literal. Did you mean "=="?
#   2.5 is 2.5
# True

# %%
5 != 3
# Out:
# True

# %%
'python' == 'Python'
# Out:
# False

# %%
'hello there' =='there hello'
# Out:
# False

# %%
'A' == 5
# Out:
# False

# %%
# check data type
type(54) == int
# Out:
# True

# %%
type(54) is float
# Out:
# False

# %% [markdown]
# ## Logical operators

# %%
5 is not 3
# Out:
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_44540\1593479670.py:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
#   5 is not 3
# True

# %%
not 5 is 3
# Out:
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_44540\1792970069.py:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
#   not 5 is 3
# True

# %%
print(True and False)
print(True and True)
print(False and False)
print(False and True)
# Out:
# False
# True
# False
# False

# %%
5 > 3 and 10 < 9
# Out:
# False

# %%
5 > 3 & 10 < 9
# note why this is different from the previous one
#bitwise operator & ， has higher precedence than comparison operator >
#equals to 5 > (3 & 10) < 9
#equals to (5>2) and (2<9)
# Out:
# True

# %%
5 > 3 or 10 < 9
# Out:
# True

# %%
5 > 3 | 10 < 9
# note why this is different from the previous one
# Out:
# False

# %%
3 < 5 < 9
# Out:
# True

# %% [markdown]
# # `if` statement

# %% [markdown]
# ## Simple  conditions

# %%
temp = 15
if float(temp) < 20:
    print('A cold day!')
# Out:
# A cold day!

# %%
if True:
    print('Python is such a powerful language!')
# Out:
# Python is such a powerful language!

# %%
x = 5

if x == 5: print('Equals 5')  # also ok to place them in the same line
if x > 4: print('Greater than 4')
if x >= 5: print('Greater than or Equals 5')   # fine to have spaces in the condition
if x < 6: print('Less than 6')
if x != 6: print('Not equal 6')
# Out:
# Equals 5
# Greater than 4
# Greater than or Equals 5
# Less than 6
# Not equal 6

# %% [markdown]
# ## Identation

# %%
x = 5
if x > 2:
    print('Bigger than 2')
    print('Still bigger')
    print('Done with 2')
for i in range(5):
    print(i)
    if i > 2:
        print('Bigger than 2')
    print('Done with i', i)  # print is in the "for" block not "if" block
print('All Done')
# Out:
# Bigger than 2
# Still bigger
# Done with 2
# 0
# Done with i 0
# 1
# Done with i 1
# 2
# Done with i 2
# 3
# Bigger than 2
# Done with i 3
# 4
# Bigger than 2
# Done with i 4
# All Done

# %% [markdown]
# ## Chained Decisions

# %%
x = 3 if 7 > 4 else -1    # although simple, but not recommended for beginners
x
# Out:
# 3

# %%
x = 9
if x < 2:
    print('Below 2')
elif x < 20:
    print('Below 20')
elif x < 10:
    print('Below 10')
else:
    print('Something else')   # what is the problem
# Out:
# Below 20

# %%
x = 9
if x < 2:
    print('Below 2')
elif x < 10:
    print('Below 10')
elif x < 20:
    print('Below 20')
else:
    print('Something else')   # pay attention to the sequence, either ascending or descending
# Out:
# Below 10
